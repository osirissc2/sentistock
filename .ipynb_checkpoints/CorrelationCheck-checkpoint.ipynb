# %%
import pandas as pd

# %%
twitter_dir = 'data/in/twitter/'
news_dir = 'data/in/news/'
stock_dir = 'data/out/'

# %%
influencers = ['BarackObama','cnnbrk', 'KimKardashian']
sources = ['New York Times', 'CNN', 'Washington Post']
out = ['VIX Future']

# %%
first_date = pd.to_datetime('1/1/2015')
last_date = pd.to_datetime('1/1/2017')

# %%
dfs_twitter = []
for influencer in influencers:
    df = pd.read_csv(twitter_dir+influencer+'.csv', parse_dates=['Date'])
    df['Date']= pd.to_datetime(df['Date'].dt.normalize())
    df = df[df['Date']<last_date]
    df = df[df['Date']>first_date]
    dfs_twitter.append(df)

# %%
dfs_news = []
for source in sources:
    df = pd.read_csv(news_dir+source+'.csv', parse_dates=['Date'])
    df['Date']= pd.to_datetime(df['Date'].dt.normalize())
    df = df[df['Date']<last_date]
    df = df[df['Date']>first_date]
    dfs_twitter.append(df)

# %%
data_VIX = pd.read_csv('VIX.csv', parse_dates=['Date'])
data_Obama = pd.read_csv('BarackObama.csv', parse_dates=['Date'])
data_NYT = pd.read_csv('New York Times.csv', parse_dates=['Date'])

# %%
data_Obama['Date']= pd.to_datetime(data_Obama['Date'].dt.normalize())
data_VIX['Date']= pd.to_datetime(data_VIX['Date'].dt.normalize())
data_NYT['Date']= pd.to_datetime(data_NYT['Date']).dt.normalize()

# %%
data_NYT
# Out:
#                                                    title               author  \
# 0      37 Who Saw Murder Didn't Call the Police - The...                  NaN
# 1                   The Pillow Cure - The New York Times       Penelope Green
# 2         John Ashbery: By the Book - The New York Times                  NaN
# 3      Drink to Your Health (in Moderation), the Scie...     Aaron E. Carroll
# 4      Simple Rules for Healthy Eating - The New York...     Aaron E. Carroll
# ...                                                  ...                  ...
# 30252  How a Trump Adviser Repeatedly Sought a Meetin...          Troy Griggs
# 30253  Satellite Images Show 1,800 Buildings Destroye...       Anjali Singhvi
# 30254  Trump Could Save More Than $1 Billion Under Hi...        Jesse Drucker
# 30255  Opinion | The Republican’s Guide to Presidenti...  The Editorial Board
# 30256  Opinion | Who Can Beat Trump in 2020? - The Ne...       Jason Zengerle
#
#             Date  sentiment_score
# 0     2014-05-08          -0.6908
# 1     2015-03-26           0.0000
# 2     2015-05-13           0.0000
# 3     2015-12-22           0.0000
# 4     2015-12-28           0.4019
# ...          ...              ...
# 30252        NaT           0.0000
# 30253        NaT          -0.6808
# 30254        NaT           0.4939
# 30255        NaT           0.0000
# 30256        NaT           0.0000
#
# [30257 rows x 4 columns]

# %%
data_Obama
# Out:
#            Date       author  \
# 0    2014-01-08  BarackObama
# 1    2014-01-08  BarackObama
# 2    2014-01-08  BarackObama
# 3    2014-01-08  BarackObama
# 4    2014-01-08  BarackObama
# ...         ...          ...
# 2858 2016-12-10  BarackObama
# 2859 2016-12-10  BarackObama
# 2860 2016-12-10  BarackObama
# 2861 2016-12-10  BarackObama
# 2862 2017-10-01  BarackObama
#
#                                                 content  number_of_likes  \
# 0     Make #53 special for #44: http://t.co/leGTnedv...             1512
# 1     Job growth has exceeded 200,000 for the sixth ...              816
# 2     Happening now: President Obama delivers a stat...              491
# 3     "That's the longest streak of private sector j...              804
# 4     "The fact is we could be much further along .....             1505
# ...                                                 ...              ...
# 2858  Let's leave our children and grandchildren a p...            12072
# 2859  Last week, more than 190 countries reached a l...             3283
# 2860  Support the bold steps we're taking against cl...             1979
# 2861  LIVE: President Obama is speaking at a recepti...             1931
# 2862  Tonight, President Obama reflects on eight yea...            38884
#
#       number_of_shares  sentiment_score
# 0                  726           0.4019
# 1                  556           0.4854
# 2                  288           0.0000
# 3                  619           0.6249
# 4                 1260           0.0000
# ...                ...              ...
# 2858              3692          -0.0516
# 2859               855           0.1779
# 2860               496           0.7783
# 2861               468           0.5719
# 2862              9568           0.4215
#
# [2863 rows x 6 columns]

# %%
data_Obama = data_Obama[data_Obama['Date']<last_date]
data_Obama = data_Obama[data_Obama['Date']>first_date]
data_VIX = data_VIX[data_VIX['Date']<last_date]
data_VIX = data_VIX[data_VIX['Date']>first_date]
data_NYT = data_NYT[data_NYT['Date']<last_date]
data_NYT = data_NYT[data_NYT['Date']>first_date]

# %%
data_VIX['Lag 2 Price'] = data_VIX['Price'].shift(-2)
data_VIX['2 Day Change'] = (data_VIX['Lag 2 Price'] - data_VIX['Price'])/data_VIX['Price']

# %%
data_VIX
# Out:
#            Date  Price    Change  Lag 2 Price  2 Day Change
# 3773 2015-01-02  17.76  0.116279        20.33      0.144707
# 3774 2015-01-05  19.19  0.080518        20.15      0.050026
# 3775 2015-01-06  20.33  0.059406        17.93     -0.118052
# 3776 2015-01-07  20.15 -0.008854        16.44     -0.184119
# 3777 2015-01-08  17.93 -0.110174        18.02      0.005020
# ...         ...    ...       ...          ...           ...
# 4272 2016-12-23  11.38  0.005300        11.89      0.044815
# 4273 2016-12-27  12.26  0.077329        13.15      0.072594
# 4274 2016-12-28  11.89 -0.030179        13.20      0.110177
# 4275 2016-12-29  13.15  0.105971          NaN           NaN
# 4276 2016-12-30  13.20  0.003802          NaN           NaN
#
# [504 rows x 5 columns]

# %%
data_NYT
# Out:
#                                                   title            author  \
# 1                  The Pillow Cure - The New York Times    Penelope Green
# 2        John Ashbery: By the Book - The New York Times               NaN
# 3     Drink to Your Health (in Moderation), the Scie...  Aaron E. Carroll
# 4     Simple Rules for Healthy Eating - The New York...  Aaron E. Carroll
# 5     The Secret to Good Toast? It’s Your Freezer - ...   Emily Weinstein
# ...                                                 ...               ...
# 3636  Whitney Houston, Cher, Tina Turner and Donna S...   Erik Piepenburg
# 3637  First, a Mixtape. Then a Romance. - The New Yo...  Katherine Rosman
# 3638  Calling on Angels While Enduring the Trials of...       Andy Newman
# 3639  House Republicans Fret About Winning Their Hea...        Carl Hulse
# 3640  Pan Pan, Father to a Generation of Pandas, Die...       Erin McCann
#
#            Date  sentiment_score
# 1    2015-03-26           0.0000
# 2    2015-05-13           0.0000
# 3    2015-12-22           0.0000
# 4    2015-12-28           0.4019
# 5    2016-02-27           0.4404
# ...         ...              ...
# 3636 2016-12-30           0.0000
# 3637 2016-12-31           0.5574
# 3638 2016-12-31           0.0000
# 3639 2016-12-31           0.7650
# 3640 2016-12-31           0.0000
#
# [3640 rows x 4 columns]

# %%
df = data_Obama.groupby('Date').sum()

# %%
dfNYT = dfNYT.groupby('Date').sum()

# %%
df2 = pd.merge(data_VIX, df, how='left', on='Date', suffixes = ('VIX', 'Obama'))
df2 = pd.merge(df2, dfNYT, how='left', on='Date', suffixes = ('', 'NYT'))

# %%
df2
# Out:
#           Date  Price    Change  Lag 2 Price  2 Day Change  number_of_likes  \
# 0   2015-01-02  17.76  0.116279        20.33      0.144707              NaN
# 1   2015-01-05  19.19  0.080518        20.15      0.050026           4182.0
# 2   2015-01-06  20.33  0.059406        17.93     -0.118052          87467.0
# 3   2015-01-07  20.15 -0.008854        16.44     -0.184119          16168.0
# 4   2015-01-08  17.93 -0.110174        18.02      0.005020           9612.0
# ..         ...    ...       ...          ...           ...              ...
# 499 2016-12-23  11.38  0.005300        11.89      0.044815              NaN
# 500 2016-12-27  12.26  0.077329        13.15      0.072594              NaN
# 501 2016-12-28  11.89 -0.030179        13.20      0.110177              NaN
# 502 2016-12-29  13.15  0.105971          NaN           NaN              NaN
# 503 2016-12-30  13.20  0.003802          NaN           NaN              NaN
#
#      number_of_shares  sentiment_score   Score
# 0                 NaN              NaN     NaN
# 1              3099.0           1.2205     NaN
# 2             57145.0           0.6436     NaN
# 3              6205.0           5.6336     NaN
# 4              4116.0           1.1121     NaN
# ..                ...              ...     ...
# 499               NaN              NaN  0.3667
# 500               NaN              NaN -0.9913
# 501               NaN              NaN  2.9580
# 502               NaN              NaN  0.9901
# 503               NaN              NaN  0.1050
#
# [504 rows x 9 columns]

# %%
df2.corr()
# Out:
#                      Price    Change  Lag 2 Price  2 Day Change  \
# Price             1.000000  0.200055     0.872895     -0.215229
# Change            0.200055  1.000000     0.175280     -0.045860
# Lag 2 Price       0.872895  0.175280     1.000000      0.274683
# 2 Day Change     -0.215229 -0.045860     0.274683      1.000000
# number_of_likes  -0.016306  0.031180     0.023407      0.082644
# number_of_shares -0.017743  0.039245     0.019951      0.083975
# Score             0.010019 -0.065055    -0.066094     -0.111391
#
#                   number_of_likes  number_of_shares     Score
# Price                   -0.016306         -0.017743  0.010019
# Change                   0.031180          0.039245 -0.065055
# Lag 2 Price              0.023407          0.019951 -0.066094
# 2 Day Change             0.082644          0.083975 -0.111391
# number_of_likes          1.000000          0.953408  0.098481
# number_of_shares         0.953408          1.000000  0.125824
# Score                    0.098481          0.125824  1.000000
