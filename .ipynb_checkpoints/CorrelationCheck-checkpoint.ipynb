# %%
import pandas as pd

# %%
data_VIX = pd.read_csv('VIX.csv')
data_Obama = pd.read_csv('BarackObama.csv')

# %%
data_VIX
# Out:
#             Date  Price    Change
# 0     2000-01-03  24.36       NaN
# 1     2000-01-04  24.94  0.023810
# 2     2000-01-05  27.98  0.121893
# 3     2000-01-06  26.68 -0.046462
# 4     2000-01-07  25.14 -0.057721
# ...          ...    ...       ...
# 4997  2019-11-12  12.64 -0.038783
# 4998  2019-11-13  12.91  0.021361
# 4999  2019-11-14  13.16  0.019365
# 5000  2019-11-15  12.95 -0.015957
# 5001  2019-11-18  12.95  0.000000
#
# [5002 rows x 3 columns]

# %%
data_Obama
# Out:
#              date_time       author  \
# 0     10/01/2017 23:44  BarackObama
# 1     05/11/2016 15:38  BarackObama
# 2     04/11/2016 22:16  BarackObama
# 3     04/11/2016 18:25  BarackObama
# 4     04/11/2016 16:12  BarackObama
# ...                ...          ...
# 2858  01/08/2014 18:54  BarackObama
# 2859  01/08/2014 18:46  BarackObama
# 2860  01/08/2014 17:58  BarackObama
# 2861  01/08/2014 14:57  BarackObama
# 2862  31/07/2014 21:34  BarackObama
#
#                                                 content  number_of_likes  \
# 0     Tonight, President Obama reflects on eight yea...            38884
# 1     In the weekly address, President Obama discuss...            17651
# 2     Let's keep working to keep our economy on a be...            27069
# 3     The landmark #ParisAgreement enters into force...            14168
# 4     The economy added 161,000 jobs in October, and...             9824
# ...                                                 ...              ...
# ...
