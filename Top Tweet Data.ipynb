# %%
import pandas as pd

# %%
df = pd.read_csv('tweets.csv')

# %%
df = df[[ 'date_time','author', 'content', 'number_of_likes', 'number_of_shares']]

# %%
df = df.rename(columns={'date_time':'Date'})

# %%
df
# Out:
#                    Date     author  \
# 0      12/01/2017 19:52  katyperry
# 1      11/01/2017 08:38  katyperry
# 2      11/01/2017 02:52  katyperry
# 3      11/01/2017 02:44  katyperry
# 4      10/01/2017 05:22  katyperry
# ...                 ...        ...
# 52537  06/01/2015 23:10   ddlovato
# 52538  06/01/2015 02:17   ddlovato
# 52539  05/01/2015 03:42   ddlovato
# 52540  05/01/2015 00:06   ddlovato
# 52541  05/01/2015 00:02   ddlovato
#
#                                                  content  number_of_likes  \
# 0      Is history repeating itself...?#DONTNORMALIZEH...             7900
# 1      @barackobama Thank you for your incredible gra...             3689
# 2                    Life goals. https://t.co/XIn1qKMKQl            10341
# 3                Me right now 🙏🏻 https://t.co/gW55C1wrwd            10774
# 4      SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...            17620
# ...                                                  ...              ...
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_values(by='Date')
df = df.reset_index(drop=True)

# %%
df
# Out:
#                      Date     author  \
# 0     2009-12-18 07:36:00    Twitter
# 1     2009-12-18 21:59:00    Twitter
# 2     2009-12-22 18:39:00    Twitter
# 3     2009-12-23 17:29:00    Twitter
# 4     2009-12-23 22:38:00    Twitter
# ...                   ...        ...
# 52537 2017-12-01 23:07:00    YouTube
# 52538 2017-12-01 23:08:00    YouTube
# 52539 2017-12-01 23:09:00    YouTube
# 52540 2017-12-01 23:30:00    YouTube
# 52541 2017-12-01 23:30:00  instagram
#
#                                                  content  number_of_likes  \
# 0      Twitter's DNS records were temporarily comprom...               73
# 1      Update on the DNS issue of last night: http://...               55
# 2      Look! A shiny new blog design. http://blog.twi...               53
# 3      If you use a Palm Pre, here are some reviews o...               40
# 4      Twitter acquires GeoAPI—location awareness to ...               67
# ...

# %%
influencers = data_twitter.author.unique()

# %%
for influencer in influencers:
    frame = df[df['author']==influencer]
    frame.to_csv(influencer+'.csv', index=False)
